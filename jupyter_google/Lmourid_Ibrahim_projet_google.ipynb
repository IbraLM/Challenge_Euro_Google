# %% [markdown]
# ### Chargement des modules nécessaires pour le projet
# Commencez par exécuter la cellule ci-dessous. Elle va charger tout le nécessaire pour faire fonctionner votre code.
# Si vous le lancez en ligne, __soyez patients__ (attendez que l'étoile à gauche devienne un nombre entre crochets).

# %%
include("jupy.jl")
# Out:
#    Updating registry at `~/.julia/registries/General`
#   Resolving package versions...
# No Changes to `~/.julia/environments/v1.5/Project.toml`
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`
#   Resolving package versions...
# No Changes to `~/.julia/environments/v1.5/Project.toml`
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`
# main (generic function with 1 method)

# %% [markdown]
# ### Donnéees à utiliser
#
# On rappelle les structures qui sont remplies par les méthodes de lecture de données.
#
# #### data structure for data used to compute the balance cost
# ```
# struct BalanceData
#     resource1::Int64        # first resource
#     resource2::Int64        # second resource
#     target::Int64           # target aimed for the recource consumption
#     weight::Int64           # weight of the balance cost
# end
# ```
#
# #### data struture for an instance of Google challenge problem
# ```
# struct DataGoogle
#     nbResources::Int64               # number of resources in the instance
#     transientStatus::Array{Int64}    # table indicating if each resource is transient (O/1)
#     weightLoadCost::Array{Int64}     # table indicating the weight of load cost for each resource
#
#     nbMachines::Int64                # number of machines
#     neighborhoods::Array{Int64}      # table indicating the neighborhood of each machine
#     nbNeighborhoods::Int64           # total number of neighbordhoods
#     locations::Array{Int64}          # table indicating the location of each machine
#     nbLocations::Int64               # total number of locations
#     softCapacities::Array{Int64,2}   # softcapacities[m,r] indicates the soft cap of machine m for resource r
#     hardCapacities::Array{Int64,2}   # hardcapacities[m,r] indicates the hard cap of machine m for resource r
#     machineMoveCosts::Array{Int64,2} # machineMoveCosts[m1,m2] indicates the cost for moving from m1 to m2
#
#     nbServices::Int64                # number of services
#     spreadMin::Array{Int64}          # for each service, its spread min
#     dependences::Array{Array{Int64}} # for each service, a list of dependences (service numbers)
#
#     nbProcess::Int64                 # number of processes
#     servicesProcess::Array{Int64}    # for each process  its service
#     processReq::Array{Int64,2}       # processReq[p,r] indicates the consumption of resource r by p
#     processMoveCost::Array{Int64}    # cost of moving each process p
#
#     nbBalanceCostData::Int64               # number of balance constraints
#     balanceCostDataList::Array{BalanceData} # one for each balance target
#     processMoveWeight::Int64        # weight for the process move cost
#     serviceMoveWeight::Int64        # weight for the service move cost
#     machineMoveWeight::Int64        # weight for the machine move cost
#
#     initialAssignment # for each process, id of the machine in the initial solution
# end
# ```
#
# #### slution
# ```
# struct SolutionGoogle
#     assignment::Array{Int64}
#     cost::Int64
# end
# ```

# %% [markdown]
# ### Cellule à modifier
# Insérez ci-dessous votre modèle dans la méthode **solveGoogle**.
#
# N'oubliez pas de faire un run sur la cellule quand vous avez fini.

# %%
using JuMP, Cbc  # JuMP  est la  bibliotheque  qui  sert à entrer  les  modèles
# Cbc est le  solver  utilise  pour  resoudre  les  modeles
function solveGoogle(data::DataGoogle, verbose::Bool)
   
    # Le programme a été codé en binôme par Clément Préaut et Ibrahim Lmourid
    
    #N.B. : Les @objective mis en commentaire ont servi à vérifier partiellement la correction des
    # contraintes et variables objectif par objectif (O1,O2,O3,O4,O5).
    
    #N.B : Les contraintes C5 et C6 ralentissent la résolution et ont donc été mises en commentaire.
    #Cependant, elle contiennent le résultat de nos recherches et constituent une proposition de réponse.
    
    m = Model(Cbc.Optimizer)    # on crée un modèle en précisant qu'on va utiliser Cbc
    
    
    @variable(m,x[i=1:data.nbMachines,j=1:data.nbProcess],Bin) # Processus j affecté à machine i (xij est un binaire)
    
    
    m0=data.initialAssignment  #machine initiale Sur laquelle est placé un processus donnné
    
    
    ###############################################
    #               Objectif 1
    ###############################################

    @variable(m,excess_SC[i=1:data.nbMachines,r=1:data.nbResources] >= 0,Int) 
    
    @variable(m,is_excess_SC[i=1:data.nbMachines,r=1:data.nbResources],Bin) 
    
    @constraint(m,init_excess_SC[i=1:data.nbMachines,r=1:data.nbResources],excess_SC[i,r] >= sum(data.processReq[p,r] * x[i,p] for p in 1:data.nbProcess) - data.softCapacities[i,r])
    
    #@constraint(m,check1_init_excess_SC[i=1:data.nbMachines,r=1:data.nbResources],excess_SC[i,r]<= 0 + 10^10 * is_excess_SC[i,r])
    
    #@constraint(m,check2_init_excess_SC[i=1:data.nbMachines,r=1:data.nbResources],excess_SC[i,r] <= sum(data.processReq[p,r] * x[i,p] for p in 1:data.nbProcess) - data.softCapacities[i,r] + 10^10 * (1 - is_excess_SC[i,r]) )    
    
    #@objective(m,Min, sum(data.weightLoadCost[r] * excess_SC[i,r] for i in 1:data.nbMachines, r in 1:data.nbResources))
    
    ###############################################
    
    
    
    ###############################################
    #               Objectif 2
    ###############################################
  
    
    @variable(m, excess_balance[i=1:data.nbMachines,j=1:data.nbBalanceCostData] >= 0, Int)
    
    @variable(m,is_excess_balance[i=1:data.nbMachines,j=1:data.nbBalanceCostData],Bin)
    
    @constraint(m,init_excess_balance[i=1:data.nbMachines,j=1:data.nbBalanceCostData],excess_balance[i,j] >= data.balanceCostDataList[j].target * ( data.hardCapacities[i,data.balanceCostDataList[j].resource1] - sum(data.processReq[p,data.balanceCostDataList[j].resource1] * x[i,p] for p in 1:data.nbProcess) ) - ( data.hardCapacities[i,data.balanceCostDataList[j].resource2] - sum(data.processReq[p ,data.balanceCostDataList[j].resource2] * x[i,p] for p in 1:data.nbProcess) ) )
    
    #@constraint(m,check1_int_1[i=1:data.nbMachines,j=1:data.nbBalanceCostData],excess_balance[i,j] <= 0 + 10^10 * is_excess_balance[i,j] )
    
    #@constraint(m,check2_int_1[i=1:data.nbMachines,j=1:data.nbBalanceCostData],excess_balance[i,j] <= data.balanceCostDataList[j].target * ( data.hardCapacities[i,data.balanceCostDataList[j].resource1] - sum(data.processReq[p,data.balanceCostDataList[j].resource1] * x[i,p] for p in 1:data.nbProcess) ) - ( data.hardCapacities[i,data.balanceCostDataList[j].resource2] - sum(data.processReq[p ,data.balanceCostDataList[j].resource2] * x[i,p] for p in 1:data.nbProcess) ) + 10^10 * (1 - is_excess_balance[i,j]))
    
    #@objective(m,Min, sum(data.balanceCostDataList[j].weight * excess_balance[m,j] for m in 1:data.nbMachines, j in 1:data.nbBalanceCostData))

    
    
    
    ###############################################
    #               Objectif 3
    ###############################################
    
    @variable(m,real[p in 1:data.nbProcess],Int)

    @constraint(m,check_move[p in 1:data.nbProcess],real[p] == data.processMoveCost[p]* (1 - x[m0[p],p]))

    #@objective(m,Min,sum(real[p] for p in 1:data.nbProcess))
    
    ###############################################
    
    
    ###############################################
    #               Objectif 4
    ###############################################
   
    
    @variable(m,nbMovesInService[i=1:data.nbServices] >= 0,Int) 
    
    @constraint(m,init_nbMovesInService[i=1:data.nbServices],nbMovesInService[i] == sum((1 - x[data.initialAssignment[p],p]) for p in 1:data.nbProcess if data.servicesProcess[p] == i)) #initialise ce tableau 
    
    @variable(m,max_nbMovesInService,Int) 
    
    @constraint(m,init_max_nbMovesInService[i=1:data.nbServices],max_nbMovesInService >= nbMovesInService[i]) 
    
    #@objective(m,Min,max_nbMovesInService) # minimiser 
    
    ###############################################

    
    ###############################################
    #               Objectif 5
    ###############################################
    
     #@objective(m,Min,sum(data.machineMoveCosts[data.initialAssignment[p],m]*x[m,p]  for p in 1:data.nbProcess,m in 1:data.nbMachines))
    
    ###############################################
    
    
    
    ###############################################
    #               Objectif Total
    ###############################################
    
    @objective(m,Min,max_nbMovesInService*data.serviceMoveWeight+sum(data.machineMoveCosts[data.initialAssignment[p],m]*x[m,p] for p in 1:data.nbProcess,m in 1:data.nbMachines)*data.machineMoveWeight + data.processMoveWeight*sum(real[p] for p in 1:data.nbProcess)+sum(data.balanceCostDataList[j].weight * excess_balance[m,j] for m in 1:data.nbMachines, j in 1:data.nbBalanceCostData)+sum(data.weightLoadCost[r] * excess_SC[i,r] for i in 1:data.nbMachines, r in 1:data.nbResources))     
    
    ###############################################
    
    
    
    
    ###############################################
    #               Contrainte 1
    ###############################################
    
    for j in 1:data.nbProcess
        @constraint(m, sum(x[i,j] for i=1:data.nbMachines) == 1 )
    end
    
    ###############################################
   
    
    
    
    ###############################################
    #               Contrainte 2
    ###############################################
    
    for i in 1:data.nbMachines
        for r in 1:data.nbResources
            @constraint(m, sum(x[i,j] * data.processReq[j,r] for j=1:data.nbProcess) <= data.hardCapacities[i,r])
        end
    end
    
    ###############################################
    
    
    
    ###############################################
    #               Contrainte 3
    ###############################################
    
    for p1 in 1:data.nbProcess
        for p2 in 1:p1-1
            if data.servicesProcess[p1]==data.servicesProcess[p2] 
                for i in 1:data.nbMachines
                        @constraint(m, x[i,p1]+x[i,p2] <= 1 )
                end
            end
        end
    end
    
    
    ###############################################

    ###############################################
    #               Contrainte 4
    ###############################################
    
    
    @variable(m, serviceLocation[1:data.nbServices,1:data.nbLocations])
    @constraint(m, conServicesLocation[s=1:data.nbServices,i=1:data.nbLocations],serviceLocation[s,i]-sum(x[m,p]
            for m=1:data.nbMachines,
                p=1:data.nbProcess
                if
                    data.servicesProcess[p] == s && data.locations[m] == i) == 0)
    @constraint(m, C4[s=1:data.nbServices], sum(1 for i=1:data.nbLocations if serviceLocation[s,i] != 0)
        >= data.spreadMin[s])
    
    ###############################################
    
    
    ###############################################
    #               Contrainte 5
    ###############################################
    #@variable(m,belong_service[p=1:data.nbProcess,s=1:data.nbServices],Bin)
    #@variable(m,is_dependence[s=1:data.nbServices,d=1:data.nbServices],Bin)
    #for i in 1:data.nbMachines
     #   for p in 1:data.nbProcess
      #      for d in 1:data.nbServices
       #         if is_dependence[data.servicesProcess[p],d] == 1
        #            @constraint(m,sum(belong_service[p_v,d]*x[data.neighborhoods[i],p_v] for p_v in 1:data.nbProcess) >= 1)
         #       end
          #  end
       # end
    #end
    
    ###############################################
    
    
    ###############################################
    #               Contrainte 6
    ###############################################
    
    #@variable(m,is_init[i=1:data.nbMachines,j=1:data.nbProcess],Bin) #Indique si la machine est l'initiale du processus considéré
    
    #for i in 1:data.nbMachines 
    #    for p in 1:data.nbProcess
    #        if m0[p] == i
    #            @constraint(m,is_init[i,p] == 1)
    #        else
    #            @constraint(m,is_init[i,p] == 0)
    #        end
    #    end
    #end
    
    #for i in 1:data.nbMachines
    #    for r in 1:data.nbResources
    #        if data.transientStatus[r]==1
    #            @constraint(m, sum(data.processReq[j,r]*is_init[i,j] for j=1:data.nbProcess) + sum(x[i,j] * data.processReq[j,r] for j=1:data.nbProcess) - sum(x[m0[j],j] * data.processReq[j,r] for j=1:data.nbProcess) <= data.hardCapacities[i,r])
    #        end
    #    end
    #end
    ###############################################
    
    
    ###############################################
    #               Résolution du modèle
    ###############################################
    
    set_optimizer_attribute(m, "seconds", 600)
   
    #print(m)        # affichage du modèle
    JuMP.optimize!(m)    # resolution à l'aide du solveur
    #########
    objVal = JuMP.objective_value(m) # to be replaced by the objective value 
    soluce = Array{Int64}(undef, data.nbProcess) # create an empty table
    for i in 1:data.nbProcess
        soluce[i] = round((sum(k*JuMP.value(x[k,i]) for k=1:data.nbMachines)))  # to be replaced by the assignment found by your model
    end
    return SolutionGoogle(soluce,objVal)
    
end
# Out:
# solveGoogle (generic function with 1 method)

# %% [markdown]
# ### Cellule de test
# La cellule ci-dessous permet d'exécuter le code. Elle lit la donnée, lance votre méthode solveGoogle, récupère la solution, et vérifie le respect des contraintes et son coût.
#
# Vous pouvez modifier le nom pour tester sur un autre jeu de donnée.

# %%
# enter your instance name here 
donnee = "a1_5"  # possibles values a1_1, a1_2, a1_3, a1_4, a1_5, a2_1, a2_2, a2_3, a2_4, a2_5 

# set to yes if you want to print intermediate logs
verbose = false

main("model_"*donnee*".txt","assignment_"*donnee*".txt",verbose)
# Out:
# Received instance files model_a1_5.txt and assignment_a1_5.txt
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Jan  1 1970
#
# command line - Cbc_C_Interface -seconds 600 -solve -quit (default strategy 1)
# seconds was changed from 1e+100 to 600
# Continuous objective value is 7.27578e+08 - 1.04 seconds
# Cgl0003I 0 fixed, 61 tightened bounds, 324 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 72 strengthened rows, 0 substitutions
# Cgl0004I processed model has 2209 rows, 12061 columns (12061 integer (12000 of which binary)) and 122389 elements
# Cbc0031I 7 added rows had average density of 908
# Cbc0013I At root node, 7 cuts changed objective from 7.275783e+08 to 7.275783e+08 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.118 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.268 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.033 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.083 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.027 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 2 row cuts average 350.0 elements, 0 column cuts (0 active)  in 0.232 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 6 row cuts average 1001.0 elements, 0 column cuts (0 active)  in 0.100 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree
# Cbc0010I After 3000 nodes, 2578 on tree, 1e+50 best solution, best possible 7.275783e+08 (116.91 seconds)
# Cbc0010I After 3100 nodes, 2678 on tree, 1e+50 best solution, best possible 7.275783e+08 (119.43 seconds)
# Cbc0010I After 3200 nodes, 2778 on tree, 1e+50 best solution, best possible 7.275783e+08 (121.57 seconds)
# Cbc0010I After 3300 nodes, 2878 on tree, 1e+50 best solution, best possible 7.275783e+08 (123.75 seconds)
# Cbc0010I After 3400 nodes, 2978 on tree, 1e+50 best solution, best possible 7.275783e+08 (126.11 seconds)
# Cbc0010I After 3500 nodes, 3078 on tree, 1e+50 best solution, best possible 7.275783e+08 (128.33 seconds)
# Cbc0010I After 3600 nodes, 3178 on tree, 1e+50 best solution, best possible 7.275783e+08 (130.76 seconds)
# Cbc0010I After 3700 nodes, 3278 on tree, 1e+50 best solution, best possible 7.275783e+08 (133.10 seconds)
# Cbc0010I After 3800 nodes, 3378 on tree, 1e+50 best solution, best possible 7.275783e+08 (135.17 seconds)
# Cbc0010I After 3900 nodes, 3478 on tree, 1e+50 best solution, best possible 7.275783e+08 (137.34 seconds)
# Cbc0010I After 4000 nodes, 3578 on tree, 1e+50 best solution, best possible 7.275783e+08 (139.58 seconds)
# Cbc0010I After 4100 nodes, 3678 on tree, 1e+50 best solution, best possible 7.275783e+08 (141.67 seconds)
# Cbc0010I After 4200 nodes, 3778 on tree, 1e+50 best solution, best possible 7.275783e+08 (143.88 seconds)
# Cbc0010I After 4300 nodes, 3878 on tree, 1e+50 best solution, best possible 7.275783e+08 (145.94 seconds)
# Cbc0010I After 4400 nodes, 3978 on tree, 1e+50 best solution, best possible 7.275783e+08 (148.08 seconds)
# Cbc0010I After 4500 nodes, 4078 on tree, 1e+50 best solution, best possible 7.275783e+08 (150.19 seconds)
# Cbc0010I After 4600 nodes, 4178 on tree, 1e+50 best solution, best possible 7.275783e+08 (152.35 seconds)
# Cbc0010I After 4700 nodes, 4278 on tree, 1e+50 best solution, best possible 7.275783e+08 (154.35 seconds)
# Cbc0010I After 4800 nodes, 4378 on tree, 1e+50 best solution, best possible 7.275783e+08 (156.40 seconds)
# Cbc0010I After 4900 nodes, 4478 on tree, 1e+50 best solution, best possible 7.275783e+08 (158.36 seconds)
# Cbc0010I After 5000 nodes, 4578 on tree, 1e+50 best solution, best possible 7.275783e+08 (160.55 seconds)
# Cbc0012I Integer solution of 7.6109291e+08 found by DiveCoefficient after 37296 iterations and 5002 nodes (160.77 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 19 rows 21 columns
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 70 rows 81 columns
# Cbc0010I After 5100 nodes, 4628 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (166.00 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 70 rows 96 columns
# Cbc0010I After 5200 nodes, 4675 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (171.29 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 70 rows 85 columns
# Cbc0010I After 5300 nodes, 4724 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (177.23 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 70 rows 84 columns
# Cbc0010I After 5400 nodes, 4774 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (183.36 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 68 rows 87 columns
# Cbc0010I After 5500 nodes, 4824 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (188.36 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 68 rows 89 columns
# Cbc0010I After 5600 nodes, 4874 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (192.67 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 68 rows 90 columns
# Cbc0010I After 5700 nodes, 4924 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (197.41 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 71 rows 94 columns
# Cbc0010I After 5800 nodes, 4974 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (202.32 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 69 rows 94 columns
# Cbc0010I After 5900 nodes, 5024 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (207.55 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 70 rows 97 columns
# Cbc0010I After 6000 nodes, 5074 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (212.63 seconds)
# Cbc0010I After 6100 nodes, 5123 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (217.54 seconds)
# Cbc0010I After 6200 nodes, 5173 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (222.41 seconds)
# Cbc0010I After 6300 nodes, 5224 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (227.88 seconds)
# Cbc0010I After 6400 nodes, 5273 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (232.46 seconds)
# Cbc0010I After 6500 nodes, 5323 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (237.99 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 68 rows 91 columns
# Cbc0010I After 6600 nodes, 5373 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (243.27 seconds)
# Cbc0010I After 6700 nodes, 5425 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (248.60 seconds)
# Cbc0010I After 6800 nodes, 5473 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (253.94 seconds)
# Cbc0010I After 6900 nodes, 5524 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (259.11 seconds)
# Cbc0010I After 7000 nodes, 5573 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (264.37 seconds)
# Cbc0010I After 7100 nodes, 5623 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (270.45 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 71 rows 97 columns
# Cbc0010I After 7200 nodes, 5674 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (275.91 seconds)
# Cbc0010I After 7300 nodes, 5724 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (281.38 seconds)
# Cbc0010I After 7400 nodes, 5773 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (286.59 seconds)
# Cbc0010I After 7500 nodes, 5823 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (291.59 seconds)
# Cbc0010I After 7600 nodes, 5873 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (296.88 seconds)
# Cbc0010I After 7700 nodes, 5924 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (301.89 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 71 rows 97 columns
# Cbc0010I After 7800 nodes, 5973 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (307.22 seconds)
# Cbc0010I After 7900 nodes, 6024 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (312.39 seconds)
# Cbc0010I After 8000 nodes, 6073 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (317.94 seconds)
# Cbc0010I After 8100 nodes, 6123 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (323.31 seconds)
# Cbc0010I After 8200 nodes, 6174 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (328.43 seconds)
# Cbc0010I After 8300 nodes, 6223 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (333.76 seconds)
# Cbc0010I After 8400 nodes, 6176 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (336.30 seconds)
# Cbc0010I After 8500 nodes, 6126 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (338.49 seconds)
# Cbc0010I After 8600 nodes, 6076 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (340.64 seconds)
# Cbc0010I After 8700 nodes, 6026 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (342.89 seconds)
# Cbc0010I After 8800 nodes, 5976 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (345.03 seconds)
# Cbc0010I After 8900 nodes, 5926 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (347.24 seconds)
# Cbc0010I After 9000 nodes, 5876 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (349.43 seconds)
# Cbc0010I After 9100 nodes, 5778 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (350.62 seconds)
# Cbc0010I After 9200 nodes, 5678 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 
# Cost : 761092913
# Checking the size of the vector
# Test passed
# Checking that the values in the solution are machine indices
# Test passed
# Checking capacity constraint (without transient)
# Test passed
# Checking capacity constraint (with transient)
# Test passed
# Checking disjunctions between processes of the same service
# Test passed
# Checking spread constraints
# Test passed
# Checking dependency constraints
# Test passed
# All tests passed: solution feasible
# Load cost = 6.324006e8
# Balance cost = 125276580
# Process move cost = 3
# Machine move cost = 0
# Service move cost = 1.0
# Objective function = 7.57677193e8
# Objective recorded in the solution 761092913
# The two costs do not match
# le 7.2757836e+08 (470.66 seconds)
# Cbc0010I After 15700 nodes, 750 on tree, 7.6109291e+08 best solution, best possible 7.2757837e+08 (472.88 seconds)
# Cbc0010I After 15800 nodes, 700 on tree, 7.6109291e+08 best solution, best possible 7.2757837e+08 (475.01 seconds)
# Cbc0010I After 15900 nodes, 655 on tree, 7.6109291e+08 best solution, best possible 7.2757838e+08 (477.18 seconds)
# Cbc0010I After 16000 nodes, 609 on tree, 7.6109291e+08 best solution, best possible 7.2757839e+08 (479.36 seconds)
# Cbc0010I After 16100 nodes, 573 on tree, 7.6109291e+08 best solution, best possible 7.2757839e+08 (481.56 seconds)
# Cbc0010I After 16200 nodes, 525 on tree, 7.6109291e+08 best solution, best possible 7.2757841e+08 (483.75 seconds)
# Cbc0010I After 16300 nodes, 479 on tree, 7.6109291e+08 best solution, best possible 7.2757844e+08 (485.94 seconds)
# Cbc0010I After 16400 nodes, 398 on tree, 7.6109291e+08 best solution, best possible 7.2757862e+08 (487.87 seconds)
# Cbc0010I After 16500 nodes, 298 on tree, 7.6109291e+08 best solution, best possible 7.2757907e+08 (489.62 seconds)
# Cbc0010I After 16600 nodes, 198 on tree, 7.6109291e+08 best solution, best possible 7.2758078e+08 (491.36 seconds)
# Cbc0010I After 16700 nodes, 98 on tree, 7.6109291e+08 best solution, best possible 7.2760095e+08 (493.11 seconds)
# Cbc0001I Search completed - best objective 761092913, took 135946 iterations and 16800 nodes (494.82 seconds)
# Cbc0032I Strong branching done 5388 times (136337 iterations), fathomed 0 nodes and fixed 0 variables
# Cbc0035I Maximum depth 4000, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 7.27578e+08 to 7.27578e+08
# Probing was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.118 seconds)
# Gomory was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.268 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.033 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.083 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.027 seconds)
# TwoMirCuts was tried 3 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.232 seconds)
# ZeroHalf was tried 3 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.100 seconds)
# Cgl0014I Postprocessing changed objective from 5.7907035e+16 to 7.6109291e+08 - possible tolerance issue - try without preprocessing
#
# Result - Optimal solution found
#
# Objective value:                761092913.00000000
# Enumerated nodes:               16800
# Total iterations:               135946
# Time (CPU seconds):             495.07
# Time (Wallclock seconds):       503.78
#
# Total time (CPU seconds):       495.07   (Wallclock seconds):       503.78
