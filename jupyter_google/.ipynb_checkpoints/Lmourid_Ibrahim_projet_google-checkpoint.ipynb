# %% [markdown]
# ### Chargement des modules nécessaires pour le projet
# Commencez par exécuter la cellule ci-dessous. Elle va charger tout le nécessaire pour faire fonctionner votre code.
# Si vous le lancez en ligne, __soyez patients__ (attendez que l'étoile à gauche devienne un nombre entre crochets).

# %%
include("jupy.jl")
# Out:
#    Updating registry at `~/.julia/registries/General`
#   Resolving package versions...
# No Changes to `~/.julia/environments/v1.5/Project.toml`
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`
#   Resolving package versions...
# No Changes to `~/.julia/environments/v1.5/Project.toml`
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`
# main (generic function with 1 method)

# %% [markdown]
# ### Donnéees à utiliser
#
# On rappelle les structures qui sont remplies par les méthodes de lecture de données.
#
# #### data structure for data used to compute the balance cost
# ```
# struct BalanceData
#     resource1::Int64        # first resource
#     resource2::Int64        # second resource
#     target::Int64           # target aimed for the recource consumption
#     weight::Int64           # weight of the balance cost
# end
# ```
#
# #### data struture for an instance of Google challenge problem
# ```
# struct DataGoogle
#     nbResources::Int64               # number of resources in the instance
#     transientStatus::Array{Int64}    # table indicating if each resource is transient (O/1)
#     weightLoadCost::Array{Int64}     # table indicating the weight of load cost for each resource
#
#     nbMachines::Int64                # number of machines
#     neighborhoods::Array{Int64}      # table indicating the neighborhood of each machine
#     nbNeighborhoods::Int64           # total number of neighbordhoods
#     locations::Array{Int64}          # table indicating the location of each machine
#     nbLocations::Int64               # total number of locations
#     softCapacities::Array{Int64,2}   # softcapacities[m,r] indicates the soft cap of machine m for resource r
#     hardCapacities::Array{Int64,2}   # hardcapacities[m,r] indicates the hard cap of machine m for resource r
#     machineMoveCosts::Array{Int64,2} # machineMoveCosts[m1,m2] indicates the cost for moving from m1 to m2
#
#     nbServices::Int64                # number of services
#     spreadMin::Array{Int64}          # for each service, its spread min
#     dependences::Array{Array{Int64}} # for each service, a list of dependences (service numbers)
#
#     nbProcess::Int64                 # number of processes
#     servicesProcess::Array{Int64}    # for each process  its service
#     processReq::Array{Int64,2}       # processReq[p,r] indicates the consumption of resource r by p
#     processMoveCost::Array{Int64}    # cost of moving each process p
#
#     nbBalanceCostData::Int64               # number of balance constraints
#     balanceCostDataList::Array{BalanceData} # one for each balance target
#     processMoveWeight::Int64        # weight for the process move cost
#     serviceMoveWeight::Int64        # weight for the service move cost
#     machineMoveWeight::Int64        # weight for the machine move cost
#
#     initialAssignment # for each process, id of the machine in the initial solution
# end
# ```
#
# #### slution
# ```
# struct SolutionGoogle
#     assignment::Array{Int64}
#     cost::Int64
# end
# ```

# %% [markdown]
# ### Cellule à modifier
# Insérez ci-dessous votre modèle dans la méthode **solveGoogle**.
#
# N'oubliez pas de faire un run sur la cellule quand vous avez fini.

# %%
using JuMP, Cbc  # JuMP  est la  bibliotheque  qui  sert à entrer  les  modèles
# Cbc est le  solver  utilise  pour  resoudre  les  modeles
function solveGoogle(data::DataGoogle, verbose::Bool)
   
    # Le programme a été codé en binôme par Clément Préaut et Ibrahim Lmourid
    
    #N.B. : Les @objective mis en commentaire ont servi à vérifier partiellement la correction des
    # contraintes et variables objectif par objectif (O1,O2,O3,O4,O5).
    
    #N.B : Les contraintes C5 et C6 ralentissent la résolution et ont donc été mises en commentaire.
    #Cependant, elle contiennent le résultat de nos recherches et constituent une proposition de réponse.
    
    m = Model(Cbc.Optimizer)    # on crée un modèle en précisant qu'on va utiliser Cbc
    
    
    @variable(m,x[i=1:data.nbMachines,j=1:data.nbProcess],Bin) # Processus j affecté à machine i (xij est un binaire)
    
    
    m0=data.initialAssignment  #machine initiale Sur laquelle est placé un processus donnné
    
    
    ###############################################
    #               Objectif 1
    ###############################################

    @variable(m,excess_SC[i=1:data.nbMachines,r=1:data.nbResources] >= 0,Int) 
    
    @variable(m,is_excess_SC[i=1:data.nbMachines,r=1:data.nbResources],Bin) 
    
    @constraint(m,init_excess_SC[i=1:data.nbMachines,r=1:data.nbResources],excess_SC[i,r] >= sum(data.processReq[p,r] * x[i,p] for p in 1:data.nbProcess) - data.softCapacities[i,r])
    
    #@constraint(m,check1_init_excess_SC[i=1:data.nbMachines,r=1:data.nbResources],excess_SC[i,r]<= 0 + 10^10 * is_excess_SC[i,r])
    
    #@constraint(m,check2_init_excess_SC[i=1:data.nbMachines,r=1:data.nbResources],excess_SC[i,r] <= sum(data.processReq[p,r] * x[i,p] for p in 1:data.nbProcess) - data.softCapacities[i,r] + 10^10 * (1 - is_excess_SC[i,r]) )    
    
    #@objective(m,Min, sum(data.weightLoadCost[r] * excess_SC[i,r] for i in 1:data.nbMachines, r in 1:data.nbResources))
    
    ###############################################
    
    
    
    ###############################################
    #               Objectif 2
    ###############################################
  
    
    @variable(m, excess_balance[i=1:data.nbMachines,j=1:data.nbBalanceCostData] >= 0, Int)
    
    @variable(m,is_excess_balance[i=1:data.nbMachines,j=1:data.nbBalanceCostData],Bin)
    
    @constraint(m,init_excess_balance[i=1:data.nbMachines,j=1:data.nbBalanceCostData],excess_balance[i,j] >= data.balanceCostDataList[j].target * ( data.hardCapacities[i,data.balanceCostDataList[j].resource1] - sum(data.processReq[p,data.balanceCostDataList[j].resource1] * x[i,p] for p in 1:data.nbProcess) ) - ( data.hardCapacities[i,data.balanceCostDataList[j].resource2] - sum(data.processReq[p ,data.balanceCostDataList[j].resource2] * x[i,p] for p in 1:data.nbProcess) ) )
    
    #@constraint(m,check1_int_1[i=1:data.nbMachines,j=1:data.nbBalanceCostData],excess_balance[i,j] <= 0 + 10^10 * is_excess_balance[i,j] )
    
    #@constraint(m,check2_int_1[i=1:data.nbMachines,j=1:data.nbBalanceCostData],excess_balance[i,j] <= data.balanceCostDataList[j].target * ( data.hardCapacities[i,data.balanceCostDataList[j].resource1] - sum(data.processReq[p,data.balanceCostDataList[j].resource1] * x[i,p] for p in 1:data.nbProcess) ) - ( data.hardCapacities[i,data.balanceCostDataList[j].resource2] - sum(data.processReq[p ,data.balanceCostDataList[j].resource2] * x[i,p] for p in 1:data.nbProcess) ) + 10^10 * (1 - is_excess_balance[i,j]))
    
    #@objective(m,Min, sum(data.balanceCostDataList[j].weight * excess_balance[m,j] for m in 1:data.nbMachines, j in 1:data.nbBalanceCostData))

    
    
    
    ###############################################
    #               Objectif 3
    ###############################################
    
    @variable(m,real[p in 1:data.nbProcess],Int)

    @constraint(m,check_move[p in 1:data.nbProcess],real[p] == data.processMoveCost[p]* (1 - x[m0[p],p]))

    #@objective(m,Min,sum(real[p] for p in 1:data.nbProcess))
    
    ###############################################
    
    
    ###############################################
    #               Objectif 4
    ###############################################
   
    
    @variable(m,nbMovesInService[i=1:data.nbServices] >= 0,Int) 
    
    @constraint(m,init_nbMovesInService[i=1:data.nbServices],nbMovesInService[i] == sum((1 - x[data.initialAssignment[p],p]) for p in 1:data.nbProcess if data.servicesProcess[p] == i)) #initialise ce tableau 
    
    @variable(m,max_nbMovesInService,Int) 
    
    @constraint(m,init_max_nbMovesInService[i=1:data.nbServices],max_nbMovesInService >= nbMovesInService[i]) 
    
    #@objective(m,Min,max_nbMovesInService) # minimiser 
    
    ###############################################

    
    ###############################################
    #               Objectif 5
    ###############################################
    
     #@objective(m,Min,sum(data.machineMoveCosts[data.initialAssignment[p],m]*x[m,p]  for p in 1:data.nbProcess,m in 1:data.nbMachines))
    
    ###############################################
    
    
    
    ###############################################
    #               Objectif Total
    ###############################################
    
    @objective(m,Min,max_nbMovesInService*data.serviceMoveWeight+sum(data.machineMoveCosts[data.initialAssignment[p],m]*x[m,p] for p in 1:data.nbProcess,m in 1:data.nbMachines)*data.machineMoveWeight + data.processMoveWeight*sum(real[p] for p in 1:data.nbProcess)+sum(data.balanceCostDataList[j].weight * excess_balance[m,j] for m in 1:data.nbMachines, j in 1:data.nbBalanceCostData)+sum(data.weightLoadCost[r] * excess_SC[i,r] for i in 1:data.nbMachines, r in 1:data.nbResources))     
    
    ###############################################
    
    
    
    
    ###############################################
    #               Contrainte 1
    ###############################################
    
    for j in 1:data.nbProcess
        @constraint(m, sum(x[i,j] for i=1:data.nbMachines) == 1 )
    end
    
    ###############################################
   
    
    
    
    ###############################################
    #               Contrainte 2
    ###############################################
    
    for i in 1:data.nbMachines
        for r in 1:data.nbResources
            @constraint(m, sum(x[i,j] * data.processReq[j,r] for j=1:data.nbProcess) <= data.hardCapacities[i,r])
        end
    end
    
    ###############################################
    
    
    
    ###############################################
    #               Contrainte 3
    ###############################################
    
    for p1 in 1:data.nbProcess
        for p2 in 1:p1-1
            if data.servicesProcess[p1]==data.servicesProcess[p2] 
                for i in 1:data.nbMachines
                        @constraint(m, x[i,p1]+x[i,p2] <= 1 )
                end
            end
        end
    end
    
    
    ###############################################

    ###############################################
    #               Contrainte 4
    ###############################################
    
    
    @variable(m, serviceLocation[1:data.nbServices,1:data.nbLocations])
    @constraint(m, conServicesLocation[s=1:data.nbServices,i=1:data.nbLocations],serviceLocation[s,i]-sum(x[m,p]
            for m=1:data.nbMachines,
                p=1:data.nbProcess
                if
                    data.servicesProcess[p] == s && data.locations[m] == i) == 0)
    @constraint(m, C4[s=1:data.nbServices], sum(1 for i=1:data.nbLocations if serviceLocation[s,i] != 0)
        >= data.spreadMin[s])
    
    ###############################################
    
    
    ###############################################
    #               Contrainte 5
    ###############################################
    #@variable(m,belong_service[p=1:data.nbProcess,s=1:data.nbServices],Bin)
    #@variable(m,is_dependence[s=1:data.nbServices,d=1:data.nbServices],Bin)
    #for i in 1:data.nbMachines
     #   for p in 1:data.nbProcess
      #      for d in 1:data.nbServices
       #         if is_dependence[data.servicesProcess[p],d] == 1
        #            @constraint(m,sum(belong_service[p_v,d]*x[data.neighborhoods[i],p_v] for p_v in 1:data.nbProcess) >= 1)
         #       end
          #  end
       # end
    #end
    
    ###############################################
    
    
    ###############################################
    #               Contrainte 6
    ###############################################
    
    #@variable(m,is_init[i=1:data.nbMachines,j=1:data.nbProcess],Bin) #Indique si la machine est l'initiale du processus considéré
    
    #for i in 1:data.nbMachines 
    #    for p in 1:data.nbProcess
    #        if m0[p] == i
    #            @constraint(m,is_init[i,p] == 1)
    #        else
    #            @constraint(m,is_init[i,p] == 0)
    #        end
    #    end
    #end
    
    #for i in 1:data.nbMachines
    #    for r in 1:data.nbResources
    #        if data.transientStatus[r]==1
    #            @constraint(m, sum(data.processReq[j,r]*is_init[i,j] for j=1:data.nbProcess) + sum(x[i,j] * data.processReq[j,r] for j=1:data.nbProcess) - sum(x[m0[j],j] * data.processReq[j,r] for j=1:data.nbProcess) <= data.hardCapacities[i,r])
    #        end
    #    end
    #end
    ###############################################
    
    
    ###############################################
    #               Résolution du modèle
    ###############################################
    
    set_optimizer_attribute(m, "seconds", 600)
   
    #print(m)        # affichage du modèle
    JuMP.optimize!(m)    # resolution à l'aide du solveur
    #########
    objVal = JuMP.objective_value(m) # to be replaced by the objective value 
    soluce = Array{Int64}(undef, data.nbProcess) # create an empty table
    for i in 1:data.nbProcess
        soluce[i] = round((sum(k*JuMP.value(x[k,i]) for k=1:data.nbMachines)))  # to be replaced by the assignment found by your model
    end
    return SolutionGoogle(soluce,objVal)
    
end
# Out:
# solveGoogle (generic function with 1 method)

# %% [markdown]
# ### Cellule de test
# La cellule ci-dessous permet d'exécuter le code. Elle lit la donnée, lance votre méthode solveGoogle, récupère la solution, et vérifie le respect des contraintes et son coût.
#
# Vous pouvez modifier le nom pour tester sur un autre jeu de donnée.

# %%
# enter your instance name here 
donnee = "a1_5"  # possibles values a1_1, a1_2, a1_3, a1_4, a1_5, a2_1, a2_2, a2_3, a2_4, a2_5 

# set to yes if you want to print intermediate logs
verbose = false

main("model_"*donnee*".txt","assignment_"*donnee*".txt",verbose)
# Out:
# Received instance files model_a1_5.txt and assignment_a1_5.txt
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Jan  1 1970
#
# command line - Cbc_C_Interface -seconds 600 -solve -quit (default strategy 1)
# seconds was changed from 1e+100 to 600
# Continuous objective value is 7.27578e+08 - 1.15 seconds
# Cgl0003I 0 fixed, 61 tightened bounds, 324 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 72 strengthened rows, 0 substitutions
# Cgl0004I processed model has 2209 rows, 12061 columns (12061 integer (12000 of which binary)) and 122389 elements
# Cbc0031I 7 added rows had average density of 908
# Cbc0013I At root node, 7 cuts changed objective from 7.275783e+08 to 7.275783e+08 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.114 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.282 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.035 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.090 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.028 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 2 row cuts average 350.0 elements, 0 column cuts (0 active)  in 0.242 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 6 row cuts average 1001.0 elements, 0 column cuts (0 active)  in 0.102 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 7.275783e+08 (3.81 seconds)
# Cbc0010I After 100 nodes, 76 on tree, 1e+50 best solution, best possible 7.275783e+08 (24.23 seconds)
# Cbc0010I After 200 nodes, 147 on tree, 1e+50 best solution, best possible 7.275783e+08 (28.00 seconds)
# Cbc0010I After 300 nodes, 202 on tree, 1e+50 best solution, best possible 7.275783e+08 (32.29 seconds)
# Cbc0010I After 400 nodes, 255 on tree, 1e+50 best solution, best possible 7.275783e+08 (35.92 seconds)
# Cbc0010I After 500 nodes, 306 on tree, 1e+50 best solution, best possible 7.275783e+08 (39.69 seconds)
# Cbc0010I After 600 nodes, 357 on tree, 1e+50 best solution, best possible 7.275783e+08 (43.45 seconds)
# Cbc0010I After 700 nodes, 405 on tree, 1e+50 best solution, best possible 7.275783e+08 (47.36 seconds)
# Cbc0010I After 800 nodes, 479 on tree, 1e+50 best solution, best possible 7.275783e+08 (50.75 seconds)
# Cbc0010I After 900 nodes, 524 on tree, 1e+50 best solution, best possible 7.275783e+08 (54.40 seconds)
# Cbc0010I After 1000 nodes, 580 on tree, 1e+50 best solution, best possible 7.275783e+08 (58.75 seconds)
# Cbc0010I After 1100 nodes, 678 on tree, 1e+50 best solution, best possible 7.275783e+08 (66.02 seconds)
# Cbc0010I After 1200 nodes, 778 on tree, 1e+50 best solution, best possible 7.275783e+08 (69.68 seconds)
# Cbc0010I After 1300 nodes, 878 on tree, 1e+50 best solution, best possible 7.275783e+08 (72.84 seconds)
# Cbc0010I After 1400 nodes, 978 on tree, 1e+50 best solution, best possible 7.275783e+08 (75.78 seconds)
# Cbc0010I After 1500 nodes, 1078 on tree, 1e+50 best solution, best possible 7.275783e+08 (78.51 seconds)
# Cbc0010I After 1600 nodes, 1178 on tree, 1e+50 best solution, best possible 7.275783e+08 (81.21 seconds)
# Cbc0010I After 1700 nodes, 1278 on tree, 1e+50 best solution, best possible 7.275783e+08 (84.17 seconds)
# Cbc0010I After 1800 nodes, 1378 on tree, 1e+50 best solution, best possible 7.275783e+08 (87.63 seconds)
# Cbc0010I After 1900 nodes, 1478 on tree, 1e+50 best solution, best possible 7.275783e+08 (90.51 seconds)
# Cbc0010I After 2000 nodes, 1578 on tree, 1e+50 best solution, best possible 7.275783e+08 (93.30 seconds)
# Cbc0010I After 2100 nodes, 1678 on tree, 1e+50 best solution, best possible 7.275783e+08 (95.92 seconds)
# Cbc0010I After 2200 nodes, 1778 on tree, 1e+50 best solution, best possible 7.275783e+08 (98.46 seconds)
# Cbc0010I After 2300 nodes, 1878 on tree, 1e+50 best solution, best possible 7.275783e+08 (100.99 seconds)
# Cbc0010I After 2400 nodes, 1978 on tree, 1e+50 best solution, best possible 7.275783e+08 (103.74 seconds)
# Cbc0010I After 2500 nodes, 2078 on tree, 1e+50 best solution, best possible 7.275783e+08 (106.27 seconds)
# Cbc0010I After 2600 nodes, 2178 on tree, 1e+50 best solution, best possible 7.275783e+08 (108.76 seconds)
# Cbc0010I After 2700 nodes, 2278 on tree, 1e+50 best solution, best possible 7.275783e+08 (111.24 seconds)
# Cbc0010I After 2800 nodes, 2378 on tree, 1e+50 best solution, best possible 7.275783e+08 (113.61 seconds)
# Cbc0010I After 2900 nodes, 2478 on tree, 1e+50 best solution, best possible 7.275783e+08 (116.23 seconds)
# Cbc0010I After 3000 nodes, 2578 on tree, 1e+50 best solution, best possible 7.275783e+08 (118.61 seconds)
# Cbc0010I After 3100 nodes, 2678 on tree, 1e+50 best solution, best possible 7.275783e+08 (121.09 seconds)
# Cbc0010I After 3200 nodes, 2778 on tree, 1e+50 best solution, best possible 7.275783e+08 (123.23 seconds)
# Cbc0010I After 3300 nodes, 2878 on tree, 1e+50 best solution, best possible 7.275783e+08 (125.44 seconds)
# Cbc0010I After 3400 nodes, 2978 on tree, 1e+50 best solution, best possible 7.275783e+08 (127.83 seconds)
# Cbc0010I After 3500 nodes, 3078 on tree, 1e+50 best solution, best possible 7.275783e+08 (130.03 seconds)
# Cbc0010I After 3600 nodes, 3178 on tree, 1e+50 best solution, best possible 7.275783e+08 (132.46 seconds)
# Cbc0010I After 3700 nodes, 3278 on tree, 1e+50 best solution, best possible 7.275783e+08 (134.80 seconds)
# Cbc0010I After 3800 nodes, 3378 on tree, 1e+50 best solution, best possible 7.275783e+08 (136.87 seconds)
# Cbc0010I After 3900 nodes, 3478 on tree, 1e+50 best solution, best possible 7.275783e+08 (139.04 seconds)
# Cbc0010I After 4000 nodes, 3578 on tree, 1e+50 best solution, best possible 7.275783e+08 (141.28 seconds)
# Cbc0010I After 4100 nodes, 3678 on tree, 1e+50 best solution, best possible 7.275783e+08 (143.35 seconds)
# Cbc0010I After 4200 nodes, 3778 on tree, 1e+50 best solution, best possible 7.275783e+08 (145.55 seconds)
# Cbc0010I After 4300 nodes, 3878 on tree, 1e+50 best solution, best possible 7.275783e+08 (147.60 seconds)
# Cbc0010I After 4400 nodes, 3978 on tree, 1e+50 best solution, best possible 7.275783e+08 (149.72 seconds)
# Cbc0010I After 4500 nodes, 4078 on tree, 1e+50 best solution, best possible 7.275783e+08 (151.83 seconds)
# Cbc0010I After 4600 nodes, 4178 on tree, 1e+50 best solution, best possible 7.275783e+08 (153.98 seconds)
# Cbc0010I After 4700 nodes, 4278 on tree, 1e+50 best solution, best possible 7.275783e+08 (155.98 seconds)
# Cbc0010I After 4800 nodes, 4378 on tree, 1e+50 best solution, best possible 7.275783e+08 (158.00 seconds)
# Cbc0010I After 4900 nodes, 4478 on tree, 1e+50 best solution, best possible 7.275783e+08 (159.96 seconds)
# Cbc0010I After 5000 nodes, 4578 on tree, 1e+50 best solution, best possible 7.275783e+08 (162.12 seconds)
# Cbc0012I Integer solution of 7.6109291e+08 found by DiveCoefficient after 37296 iterations and 5002 nodes (162.35 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 19 rows 21 columns
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 70 rows 81 columns
# Cbc0010I After 5100 nodes, 4628 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (167.65 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 70 rows 96 columns
# Cbc0010I After 5200 nodes, 4675 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (173.01 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 70 rows 85 columns
# Cbc0010I After 5300 nodes, 4724 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (179.13 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 70 rows 84 columns
# Cbc0010I After 5400 nodes, 4774 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (185.49 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 68 rows 87 columns
# Cbc0010I After 5500 nodes, 4824 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (190.55 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 68 rows 89 columns
# Cbc0010I After 5600 nodes, 4874 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (194.94 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 68 rows 90 columns
# Cbc0010I After 5700 nodes, 4924 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (199.73 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 71 rows 94 columns
# Cbc0010I After 5800 nodes, 4974 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (204.70 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 69 rows 94 columns
# Cbc0010I After 5900 nodes, 5024 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (210.00 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 70 rows 97 columns
# Cbc0010I After 6000 nodes, 5074 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (215.10 seconds)
# Cbc0010I After 6100 nodes, 5123 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (220.16 seconds)
# Cbc0010I After 6200 nodes, 5173 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (225.12 seconds)
# Cbc0010I After 6300 nodes, 5224 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (230.65 seconds)
# Cbc0010I After 6400 nodes, 5273 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (235.24 seconds)
# Cbc0010I After 6500 nodes, 5323 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (240.79 seconds)
# Cbc0038I Full problem 2209 rows 12061 columns, reduced to 68 rows 91 columns
# Cbc0010I After 6600 nodes, 5373 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (246.11 seconds)
# Cbc0010I After 6700 nodes, 5425 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (251.54 seconds)
# Cbc0010I After 6800 nodes, 5473 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (256.95 seconds)
# Cbc0010I After 6900 nodes, 5518 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (262.10 seconds)
# Cbc0010I After 7000 nodes, 5468 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (264.32 seconds)
# Cbc0010I After 7100 nodes, 5418 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (266.55 seconds)
# Cbc0010I After 7200 nodes, 5368 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (268.74 seconds)
# Cbc0010I After 7300 nodes, 5318 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (270.95 seconds)
# Cbc0010I After 7400 nodes, 5268 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (273.14 seconds)
# Cbc0010I After 7500 nodes, 5217 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (275.32 seconds)
# Cbc0010I After 7600 nodes, 5139 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (277.51 seconds)
# Cbc0010I After 7700 nodes, 5092 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (279.72 seconds)
# Cbc0010I After 7800 nodes, 5043 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (281.95 seconds)
# Cbc0010I After 7900 nodes, 4995 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (284.24 seconds)
# Cbc0010I After 8000 nodes, 4948 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (286.44 seconds)
# Cbc0010I After 8100 nodes, 4887 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (288.63 seconds)
# Cbc0010I After 8200 nodes, 4838 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (290.82 seconds)
# Cbc0010I After 8300 nodes, 4788 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (293.02 seconds)
# Cbc0010I After 8400 nodes, 4739 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (295.23 seconds)
# Cbc0010I After 8500 nodes, 4689 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (297.45 seconds)
# Cbc0010I After 8600 nodes, 4639 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (299.62 seconds)
# Cbc0010I After 8700 nodes, 4591 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (301.85 seconds)
# Cbc0010I After 8800 nodes, 4543 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (304.08 seconds)
# Cbc0010I After 8900 nodes, 4497 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (306.31 seconds)
# Cbc0010I After 9000 nodes, 4450 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (308.50 seconds)
# Cbc0010I After 9100 nodes, 4352 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (309.73 seconds)
# Cbc0010I After 9200 nodes, 4252 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (310.93 seconds)
# Cbc0010I After 9300 nodes, 4152 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (312.15 seconds)
# Cbc0010I After 9400 nodes, 4052 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (313.40 seconds)
# Cbc0010I After 9500 nodes, 3952 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (314.66 seconds)
# Cbc0010I After 9600 nodes, 3852 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (315.94 seconds)
# Cbc0010I After 9700 nodes, 3752 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (317.22 seconds)
# Cbc0010I After 9800 nodes, 3652 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (318.54 seconds)
# Cbc0010I After 9900 nodes, 3554 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (319.91 seconds)
# Cbc0010I After 10000 nodes, 3454 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (321.21 seconds)
# Cbc0010I After 10100 nodes, 3354 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (322.59 seconds)
# Cbc0010I After 10200 nodes, 3254 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (323.96 seconds)
# Cbc0010I After 10300 nodes, 3154 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (325.36 seconds)
# Cbc0010I After 10400 nodes, 3054 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (326.76 seconds)
# Cbc0010I After 10500 nodes, 2954 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (328.14 seconds)
# Cbc0010I After 10600 nodes, 2854 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (329.54 seconds)
# Cbc0010I After 10700 nodes, 2754 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (330.94 seconds)
# Cbc0010I After 10800 nodes, 2654 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (332.35 seconds)
# Cbc0010I After 10900 nodes, 2554 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (333.80 seconds)
# Cbc0010I After 11000 nodes, 2456 on tree, 7.6109291e+08 best solution, best possible 7.275783e+08 (335.29 seconds)
# Cbc0010I After 11100 nodes, 2360 on tree, 7.6109291e+08 best solution, best possible 7.2757831e+08 (337.62 seconds)
# Cbc0010I After 11200 nodes, 2260 on tree, 7.6109291e+08 best solution, best possible 7.2757831e+08 (339.85 seconds)
# Cbc0010I After 11300 nodes, 2161 on tree, 7.6109291e+08 best solution, best possible 7.2757831e+08 (341.99 seconds)
# Cbc0010I After 11400 nodes, 2073 on tree, 7.6109291e+08 best solution, best possible 7.2757831e+08 (344.15 seconds)
# Cbc0010I After 11500 nodes, 1987 on tree, 7.6109291e+08 best solution, best possible 7.2757832e+08 (346.30 seconds)
# Cbc0010I After 11600 nodes, 1889 on tree, 7.6109291e+08 best solution, best possible 7.2757833e+08 (348.21 seconds)
# Cbc0010I After 11700 nodes, 1823 on tree, 7.6109291e+08 best solution, best possible 7.2757835e+08 (350.32 seconds)
# Cbc0010I After 11800 nodes, 1772 on tree, 7.6109291e+08 best solution, best possible 7.2757835e+08 (352.53 seconds)
# Cbc0010I After 11900 nodes, 1725 on tree, 7.6109291e+08 best solution, best possible 7.2757835e+08 (354.73 seconds)
# Cbc0010I After 12000 nodes, 1677 on tree, 7.6109291e+08 best solution, best possible 7.2757836e+08 (356.88 seconds)
# Cbc0010I After 12100 nodes, 1636 on tree, 7.6109291e+08 best solution, best possible 7.2757837e+08 (359.07 seconds)
# Cbc0010I After 12200 nodes, 1588 on tree, 7.6109291e+08 best solution, best poChecking the solution
# Solution received is [12, 3, 9, 8, 9, 4, 4, 4, 1, 1, 2, 6, 6, 5, 12, 5, 7, 6, 2, 5, 4, 9, 8, 9, 3, 8, 6, 3, 7, 7, 5, 1, 12, 12, 3, 6, 7, 8, 1, 8, 8, 1, 2, 1, 6, 9, 11, 12, 11, 10, 1, 3, 4, 10, 1, 7, 1, 2, 5, 2, 9, 12, 12, 10, 9, 4, 3, 8, 9, 1, 12, 3, 8, 8, 11, 2, 3, 7, 3, 11, 1, 6, 8, 6, 1, 9, 12, 11, 6, 8, 12, 7, 8, 3, 4, 4, 1, 7, 3, 1, 2, 2, 1, 1, 9, 4, 10, 4, 1, 7, 3, 6, 12, 5, 7, 4, 8, 12, 1, 4, 12, 9, 9, 4, 9, 5, 2, 1, 7, 4, 2, 3, 5, 4, 10, 4, 10, 12, 8, 10, 5, 10, 5, 4, 4, 7, 12, 4, 7, 3, 12, 12, 8, 7, 4, 5, 5, 8, 1, 8, 3, 4, 11, 10, 11, 4, 12, 7, 2, 10, 10, 4, 7, 10, 8, 12, 11, 1, 12, 9, 12, 5, 3, 4, 4, 12, 9, 11, 3, 4, 8, 7, 10, 8, 3, 9, 2, 8, 3, 1, 8, 7, 3, 11, 4, 10, 6, 7, 2, 1, 8, 1, 9, 4, 4, 3, 1, 3, 7, 11, 4, 7, 12, 10, 7, 2, 7, 12, 7, 2, 9, 1, 10, 2, 6, 4, 4, 10, 3, 10, 9, 4, 3, 8, 1, 2, 6, 5, 7, 4, 6, 9, 9, 4, 2, 1, 12, 12, 5, 5, 2, 4, 1, 7, 5, 4, 6, 6, 2, 2, 10, 1, 6, 7, 9, 3, 8, 6, 12, 9, 12, 8, 10, 4, 11, 8, 12, 12, 11, 1, 4, 12, 7, 2, 11, 11, 4, 4, 6, 11, 5, 4, 3, 7, 3, 6, 7, 1, 3, 3, 3, 12, 6, 4, 4, 6, 2, 10, 6, 11, 1, 3, 5, 9, 4, 4, 7, 3, 9, 3, 12, 6, 4, 1, 10, 3, 4, 8, 1, 12, 5, 6, 8, 3, 2, 10, 6, 3, 2, 11, 1, 1, 8, 3, 7, 9, 8, 3, 12, 12, 3, 9, 8, 6, 10, 9, 2, 3, 11, 11, 7, 5, 6, 9, 7, 5, 9, 6, 10, 7, 9, 2, 2, 1, 4, 1, 6, 2, 10, 7, 7, 9, 4, 6, 2, 3, 12, 4, 4, 3, 9, 9, 10, 8, 10, 1, 5, 3, 11, 12, 12, 10, 5, 10, 5, 1, 3, 7, 12, 3, 1, 2, 7, 10, 6, 5, 4, 5, 12, 4, 12, 9, 4, 12, 8, 10, 4, 1, 4, 8, 9, 4, 6, 6, 10, 10, 1, 5, 8, 2, 10, 9, 4, 8, 7, 7, 10, 10, 6, 5, 4, 6, 3, 3, 8, 10, 4, 11, 8, 8, 1, 1, 2, 9, 1, 2, 11, 11, 7, 3, 7, 7, 2, 1, 9, 2, 12, 6, 5, 11, 2, 10, 2, 7, 6, 5, 10, 5, 7, 11, 7, 12, 1, 12, 5, 6, 7, 8, 8, 2, 1, 11, 9, 4, 11, 2, 1, 3, 10, 5, 10, 1, 9, 8, 4, 10, 3, 11, 6, 9, 5, 7, 3, 6, 8, 12, 10, 10, 2, 8, 2, 5, 2, 3, 11, 11, 4, 11, 4, 4, 11, 9, 5, 8, 1, 4, 9, 5, 5, 9, 2, 4, 9, 9, 3, 2, 11, 3, 11, 2, 2, 4, 8, 7, 1, 4, 9, 1, 8, 8, 7, 4, 7, 1, 6, 8, 6, 3, 2, 11, 1, 9, 3, 12, 6, 3, 8, 1, 12, 7, 9, 9, 1, 5, 7, 7, 9, 1, 3, 5, 4, 7, 11, 5, 9, 5, 10, 3, 2, 1, 5, 1, 2, 8, 8, 8, 6, 11, 4, 4, 6, 6, 7, 5, 8, 1, 2, 2, 10, 12, 2, 4, 5, 2, 11, 10, 9, 7, 1, 3, 4, 10, 11, 6, 6, 9, 11, 4, 8, 10, 11, 9, 6, 12, 4, 2, 8, 1, 11, 6, 7, 3, 12, 10, 3, 1, 10, 3, 10, 8, 8, 12, 7, 7, 6, 9, 1, 1, 2, 11, 7, 4, 2, 12, 12, 12, 12, 2, 7, 12, 1, 1, 10, 6, 6, 5, 1, 12, 12, 8, 9, 9, 2, 8, 3, 7, 4, 4, 3, 10, 5, 9, 5, 6, 12, 6, 5, 3, 3, 7, 6, 7, 3, 9, 9, 1, 2, 11, 10, 12, 5, 3, 5, 7, 9, 10, 3, 9, 1, 6, 4, 12, 11, 5, 3, 11, 4, 6, 8, 7, 7, 2, 7, 12, 9, 1, 2, 6, 1, 3, 2, 5, 9, 5, 7, 12, 12, 7, 2, 11, 3, 6, 5, 8, 9, 9, 4, 5, 5, 3, 6, 7, 1, 8, 11, 1, 1, 8, 10, 8, 11, 8, 10, 1, 2, 4, 5, 2, 8, 1, 2, 5, 3, 2, 3, 11, 7, 2, 9, 9, 8, 6, 2, 12, 2, 1, 9, 7, 5, 9, 8, 9, 9, 5, 5, 10, 9, 6, 4, 1, 4, 3, 11, 1, 10, 10, 2, 11, 6, 8, 1, 2, 4, 1, 4, 3, 12, 4, 6, 12, 1, 9, 7, 12, 1, 10, 6, 9, 3, 12, 12, 8, 6, 11, 1, 7, 3, 6, 8, 2, 5, 11, 9, 5, 10, 10, 5, 2, 2, 10, 5, 2, 2, 12, 2, 10, 2, 9, 9, 7, 9, 10, 1, 1, 12, 6, 7, 6, 6, 7, 3, 7, 4, 8, 9, 3, 6, 3, 9, 7, 12, 4, 8, 5, 3, 1, 8, 5, 1, 7, 8, 5, 8, 3, 5, 3, 2, 10, 4, 3, 10, 11, 12, 3, 10, 11, 10, 3, 12, 10, 6, 7, 11, 12, 4, 2, 11, 8, 5, 1, 11, 4, 6, 9, 3, 7, 7, 3, 4, 9, 2, 12, 10, 4, 6, 7, 8, 10, 3, 7, 3, 1, 9, 4, 11, 1, 5, 6, 5, 4, 5, 2, 1, 12, 12, 9, 12, 10, 7, 11]
# Cost : 761092913
# Checking the size of the vector
# Test passed
# Checking that the values in the solution are machine indices
# Test passed
# Checking capacity constraint (without transient)
# Test passed
# Checking capacity constraint (with transient)
# Test passed
# Checking disjunctions between processes of the same service
# Test passed
# Checking spread constraints
# Test passed
# Checking dependency constraints
# Test passed
# All tests passed: solution feasible
# Load cost = 6.324006e8
# Balance cost = 125276580
# Process move cost = 3
# Machine move cost = 0
# Service move cost = 1.0
# Objective function = 7.57677193e8
# Objective recorded in the solution 761092913
# The two costs do not match
# ssible 7.2757838e+08 (361.17 seconds)
# Cbc0010I After 12300 nodes, 1550 on tree, 7.6109291e+08 best solution, best possible 7.2757839e+08 (363.38 seconds)
# Cbc0010I After 12400 nodes, 1509 on tree, 7.6109291e+08 best solution, best possible 7.2757841e+08 (365.56 seconds)
# Cbc0010I After 12500 nodes, 1465 on tree, 7.6109291e+08 best solution, best possible 7.2757844e+08 (367.75 seconds)
# Cbc0010I After 12600 nodes, 1378 on tree, 7.6109291e+08 best solution, best possible 7.2757862e+08 (369.64 seconds)
# Cbc0010I After 12700 nodes, 1278 on tree, 7.6109291e+08 best solution, best possible 7.2757918e+08 (371.39 seconds)
# Cbc0010I After 12800 nodes, 1178 on tree, 7.6109291e+08 best solution, best possible 7.2758087e+08 (373.13 seconds)
# Cbc0010I After 12900 nodes, 1078 on tree, 7.6109291e+08 best solution, best possible 7.2760106e+08 (374.88 seconds)
# Cbc0010I After 13000 nodes, 980 on tree, 7.6109291e+08 best solution, best possible 7.2761186e+08 (376.64 seconds)
# Cbc0010I After 13100 nodes, 886 on tree, 7.6109291e+08 best solution, best possible 7.2761186e+08 (378.15 seconds)
# Cbc0010I After 13200 nodes, 786 on tree, 7.6109291e+08 best solution, best possible 7.2761186e+08 (379.65 seconds)
# Cbc0010I After 13300 nodes, 686 on tree, 7.6109291e+08 best solution, best possible 7.2761186e+08 (381.18 seconds)
# Cbc0010I After 13400 nodes, 586 on tree, 7.6109291e+08 best solution, best possible 7.2761186e+08 (382.76 seconds)
# Cbc0010I After 13500 nodes, 486 on tree, 7.6109291e+08 best solution, best possible 7.2761186e+08 (384.34 seconds)
# Cbc0010I After 13600 nodes, 386 on tree, 7.6109291e+08 best solution, best possible 7.2761186e+08 (385.97 seconds)
# Cbc0010I After 13700 nodes, 286 on tree, 7.6109291e+08 best solution, best possible 7.2761186e+08 (387.63 seconds)
# Cbc0010I After 13800 nodes, 186 on tree, 7.6109291e+08 best solution, best possible 7.2761186e+08 (389.32 seconds)
# Cbc0010I After 13900 nodes, 88 on tree, 7.6109291e+08 best solution, best possible 7.2761186e+08 (391.00 seconds)
# Cbc0001I Search completed - best objective 761092913, took 91111 iterations and 13988 nodes (392.52 seconds)
# Cbc0032I Strong branching done 4186 times (91656 iterations), fathomed 0 nodes and fixed 0 variables
# Cbc0035I Maximum depth 4000, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 7.27578e+08 to 7.27578e+08
# Probing was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.114 seconds)
# Gomory was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.282 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.035 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.090 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.028 seconds)
# TwoMirCuts was tried 3 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.242 seconds)
# ZeroHalf was tried 3 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.102 seconds)
# Cgl0014I Postprocessing changed objective from 5.7907035e+16 to 7.6109291e+08 - possible tolerance issue - try without preprocessing
#
# Result - Optimal solution found
#
# Objective value:                761092913.00000000
# Enumerated nodes:               13988
# Total iterations:               91111
# Time (CPU seconds):             392.77
# Time (Wallclock seconds):       404.39
#
# Total time (CPU seconds):       392.77   (Wallclock seconds):       404.39
